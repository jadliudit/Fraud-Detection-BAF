# %% [markdown]
# # 🏦 Bank Account Fraud Detection — BAF Suite (NeurIPS 2022)
#
# **Notebook 2: Data Preprocessing**
#
# | | |
# |---|---|
# | **Author** | Udit Jadli |
# | **Dataset** | [Bank Account Fraud Suite (NeurIPS 2022)](https://www.kaggle.com/datasets/sgpjesus/bank-account-fraud-dataset-neurips-2022) — Feedzai |
# | **Objective** | Turn the raw data into model-ready form: handle the `-1` missing values with informative flags, encode categorical features, and split into train/test *before* any resampling to prevent leakage. |
#
#
# This notebook builds directly on the findings from Notebook 1: the ~1.1% fraud rate, the `-1` sentinel missingness, and the five categorical features identified there.

# %% [markdown]
# ---

# %% [markdown]
# ## Section 8 — Load Data & Recreate Feature Groups
#
# Each notebook runs independently, so we reload the raw data and re-establish the feature groups (numeric, categorical, protected) that we identified in Notebook 1. This keeps the notebook self-contained and reproducible.
